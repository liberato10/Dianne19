# %% [markdown]
# <a href="https://colab.research.google.com/github/liberato10/Dianne19/blob/main/GROUPBYEXERCISE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# Keep in mind that the filename will be based on your path

filename = 'YOUR PATH'

df = pd.read_csv('https://raw.githubusercontent.com/liberato10/Dianne19/main/CalIt2%20(1).csv')

df.head()
# Out:
#    7  07/24/05  00:00:00  0
# 0  9  07/24/05  00:00:00  0
# 1  7  07/24/05  00:30:00  1
# 2  9  07/24/05  00:30:00  0
# 3  7  07/24/05  01:00:00  0
# 4  9  07/24/05  01:00:00  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10079 entries, 0 to 10078
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   7         10079 non-null  int64
#  1   07/24/05  10079 non-null  object
#  2   00:00:00  10079 non-null  object
#  3   0         10079 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 315.1+ KB

# %%
df.describe().round(2)
# Out:
#              7         0
# count  10079.0  10079.00
# mean       8.0      3.81
# std        1.0      6.44
# min        7.0      0.00
# 25%        7.0      0.00
# 50%        9.0      0.00
# 75%        9.0      5.00
# max        9.0     62.00

# %%
# DataFrame before renaming columns

df.head()
# Out:
#    7  07/24/05  00:00:00  0
# 0  9  07/24/05  00:00:00  0
# 1  7  07/24/05  00:30:00  1
# 2  9  07/24/05  00:30:00  0
# 3  7  07/24/05  01:00:00  0
# 4  9  07/24/05  01:00:00  0
